# %% [markdown]
# # Fine-tune BLIP using Hugging Face `transformers`, `datasets`, `peft` 🤗 and `bitsandbytes`
#
# Let's leverage recent advances from Parameter Efficient Fine-Tuning methods to fine-tune a large image to text model! We will show through this tutorial that it is possible to fine-tune a 3B scale model (~6GB in half-precision)
#
# Here we will use a dummy dataset of [football players](https://huggingface.co/datasets/ybelkada/football-dataset) ⚽ that is uploaded on the Hub. The images have been manually selected together with the captions.
# Check the 🤗 [documentation](https://huggingface.co/docs/datasets/image_dataset) on how to create and upload your own image-text dataset.

# %% [markdown]
# ## Set-up environment

# %% [markdown]
# ## Load the image captioning dataset
#
# Let's load the image captioning dataset, you just need few lines of code for that.

# %%
from datasets import load_dataset 
from PIL import Image
import pandas as pd
import numpy as np
import torch
import random
from transformers import AutoProcessor, Blip2ForConditionalGeneration
from time import time
import re

seed=777
random.seed(seed)


def convert_floats_to_two_decimals(text):
    # Expressão regular para capturar números float
    float_pattern = r'(\d+\.\d+)'  # Captura números decimais
    # Substituir os números float por floats com 2 casas decimais
    modified_text = re.sub(float_pattern, lambda x: f"{float(x.group(1)):.2f}", text)
    return modified_text

# random.seed(seed)
# np.random.seed(seed)
# torch.manual_seed(seed)
# torch.cuda.manual_seed_all(seed)

# # Garante que algumas operações sejam determinísticas
# torch.backends.cudnn.deterministic = True
# torch.backends.cudnn.benchmark = False

#dataset = load_dataset("ybelkada/football-dataset", split="train")
#embds_path = './nodules_luna_lidc_3d_metadas_embeddings'
embds_path = './nodules_luna_lidc_3d_metadas_embeddings_isomorphic'
df = pd.read_csv('annotations_isomorphic_with_legends.csv') 

new_static_legends = []

for idx, row in df.iterrows():
    legend = str(row.static_legends)
    if 'Highly Unlikely' in legend:
        legend = legend.replace('Highly Unlikely', 'Remote')
    elif 'Moderately Unlikely' in legend:
        legend = legend.replace('Moderately Unlikely', 'Possible')
    elif 'Moderately Suspicious' in legend:
        legend = legend.replace('Moderately Suspicious', 'Doubtful')
    elif 'Highly Suspicious' in legend:
        legend = legend.replace('Highly Suspicious', 'Critical')
        #print("aqui")
#     print(legend)
    legend = convert_floats_to_two_decimals(legend)
    new_static_legends.append(legend)

df['static_legends'] = new_static_legends

print(df.shape)
#df = df.query("malignancy != 'Indeterminate'").copy()
print(df.shape)

# Pegue 80% dos dados como a primeira amostra
df_train = df.sample(frac=0.8, random_state=seed)

# Pegue os 20% restantes como a segunda amostra
df_test = df.drop(df_train.index)
#df_test.to_csv('annotations_test_with_legends_seed_777.csv')
print(df_train.shape)
print(df_test.shape)
is_training = False
is_evaluating = True
# Out:
# (1182, 15)
# (1182, 15)
# (946, 15)
# (236, 15)

# %% [markdown]
# Let's retrieve the caption of the first example:

# %% [markdown]
# ## Create PyTorch Dataset

# %% [markdown]
# Let's define below the dataset as well as the data collator!

# %%
from torch.utils.data import Dataset, DataLoader


class ImageCaptioningDataset(Dataset):
    def __init__(self, df, embds_path, processor):
        self.dataset = df
        self.processor = processor
        self.embds_path = embds_path

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        item = self.dataset.iloc[idx]
        #print(f'{self.embds_path}/{item["filename"]}')
        image = np.load(f'{self.embds_path}/{item["filename"]}')
        #print(image_rgb.min(), image_rgb.max())
        #encoding = self.processor(images=image, padding="max_length", return_tensors="pt")
        # remove batch dimension
        #encoding = {k: v.squeeze() for k, v in encoding.items()}
        #encoding["text"] = item["text"]
        #text_inputs = self.processor.tokenizer(item['report_text'] ,return_tensors="pt")
        return {'embds': torch.from_numpy(image).squeeze(0), 'text': item['static_legends']}

def collate_fn(batch):
    # pad the input_ids and attention_mask
    processed_batch = {}
    for key in batch[0].keys():
        if key != "text":
            processed_batch[key] = torch.stack([example[key] for example in batch])
        else:
            text_inputs = processor.tokenizer([example["text"] for example in batch], padding=True, return_tensors="pt")
            processed_batch["input_ids"] = text_inputs["input_ids"]
            processed_batch["attention_mask"] = text_inputs["attention_mask"]
            # processed_batch["original_text"] = [example["text"] for example in batch]
            
    return processed_batch

# %%
class VisionModelOutput:
    def __init__(self, last_hidden_state):
        self.last_hidden_state = last_hidden_state

# Adaptador para ajustar a saída do ViT3D para o Q-Former
class ViT3DAdapter(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.training = True

    def forward(self, pixel_values=None, **kwargs):
        if self.training:
            return pixel_values.unsqueeze(0)
        else:
            return VisionModelOutput(last_hidden_state=pixel_values)

# %%
processor = AutoProcessor.from_pretrained("Salesforce/blip2-opt-2.7b")

# %%
if is_training:
    device = "cuda" if torch.cuda.is_available() else "cpu"
    
    
    #model = Blip2ForConditionalGeneration.from_pretrained("ybelkada/blip2-opt-2.7b-fp16-sharded", device_map="auto", load_in_8bit=True)
    #model = Blip2ForConditionalGeneration.from_pretrained("ybelkada/blip2-opt-2.7b-fp16-sharded", 
    # _map="auto", load_in_8bit=True)
    
    model = Blip2ForConditionalGeneration.from_pretrained(
        "ybelkada/blip2-opt-2.7b-fp16-sharded",
        device_map="auto",
        torch_dtype=torch.float32
    )
    
    dtype = next(model.parameters()).dtype
    print(dtype)
    
    adapted_vit3d = ViT3DAdapter().to(device)
    model.vision_model = adapted_vit3d

# %%
# Checar se o modelo está congelado
def check_frozen_layers(model):
    frozen_layers = []
    trainable_layers = []

    for name, param in model.named_parameters():
        if param.requires_grad:
            trainable_layers.append(name)
        else:
            frozen_layers.append(name)
    
    print("Camadas congeladas:")
    for layer in frozen_layers:
        print(layer)
    
    print("\nCamadas treináveis:")
    for layer in trainable_layers:
        print(layer)

#check_frozen_layers(model)

# %% [markdown]
# Next we define our `LoraConfig` object. We explicitly tell

# %%
if is_training:
    from peft import LoraConfig, get_peft_model
    import torch
    
    
    # Let's define the LoraConfig
    config = LoraConfig(
        r=16,
        lora_alpha=32,
        lora_dropout=0.05,
        bias="none",
        target_modules=["q_proj", "k_proj"]
    )
    
    model = get_peft_model(model, config)
    model.print_trainable_parameters()
    
    # Congelar todas as camadas do modelo, exceto o Q-Former (apenas q_proj e k_proj)
    # for name, param in model.named_parameters():
    #     # Mantenha apenas as camadas do Q-Former como treináveis e cheque o tipo de dado
    #     if "qformer" in name:
    #         #if ('attention' in name or 'crossattention' in name) and torch.is_floating_point(param):
    #         param.requires_grad = True
    #     else:
    #         param.requires_grad = False
    
    # Congelar todas as camadas do modelo, exceto o Q-Former
    # for name, param in model.named_parameters():
    #     # Checar se o parâmetro faz parte do Q-Former e se é de ponto flutuante
    #     if "qformer" in name and torch.is_floating_point(param):
    #         param.requires_grad = True
    #     else:
    #         param.requires_grad = False
    
    
    # Configurar todos os parâmetros como treináveis, verificando se são de ponto flutuante
    # for param in model.parameters():
    #     if torch.is_floating_point(param):
    #         param.requires_grad = True
    
    # Exibir parâmetros treináveis para verificação
    print("Parâmetros treináveis no Q-Former:")
    for name, param in model.named_parameters():
        if param.requires_grad:
            # print(name)
            pass
    #model.print_trainable_parameters()

# %% [markdown]
# Now that we have loaded the processor, let's load the dataset and the dataloader:

# %%
train_dataset = ImageCaptioningDataset(df_train, embds_path, processor)
test_dataset = ImageCaptioningDataset(df_test, embds_path, processor)
# train_dataset_ = train_dataset_[:100]
train_dataloader = DataLoader(train_dataset, shuffle=True, batch_size=4, collate_fn=collate_fn)
test_dataloader = DataLoader(test_dataset, shuffle=True, batch_size=4, collate_fn=collate_fn)
#train_dataloader = DataLoader(train_dataset, shuffle=True, batch_size=4)

# %%
for i in range(10):
    print(f"Sample {i+1}")    
    d = train_dataset[i]
    print("LIDC-LUNA Image embed: ", d['embds'])
    print("Text Report: ", d['text'])
    print("-"*150)
# Out:
# Sample 1
# LIDC-LUNA Image embed:  tensor([[ 1.1043,  1.2375, -0.9351,  ..., -0.2086, -0.6986, -0.0975],
#         [ 1.1425,  1.2203, -0.9613,  ..., -0.1956, -0.7696, -0.1241],
#         [ 1.1953,  1.2541, -0.9522,  ..., -0.3007, -0.7236, -0.1164],
#         ...,
#         [ 1.1469,  1.2849, -1.0146,  ..., -0.2580, -0.7015, -0.0449],
#         [ 1.1134,  1.2949, -0.9030,  ..., -0.2477, -0.7227, -0.0767],
#         [ 1.1456,  1.3453, -0.9390,  ..., -0.2839, -0.7031, -0.0501]])
# Text Report:  The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: Near Marked Lobulation, spiculation: No Spiculation, texture: Non-Solid/GGO, malignancy: Indeterminate, diameter: 5.70 mm, volume: 49.45 mm3.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Sample 2
# LIDC-LUNA Image embed:  tensor([[ 1.0869,  1.2358, -0.9346,  ..., -0.1892, -0.7044, -0.1486],
#         [ 1.1199,  1.2157, -0.9582,  ..., -0.1788, -0.7779, -0.1814],
#         [ 1.1761,  1.2477, -0.9508,  ..., -0.2816, -0.7357, -0.1733],
#         ...,
#         [ 1.1289,  1.2803, -1.0082,  ..., -0.2384, -0.7077, -0.0995],
#         [ 1.0944,  1.2933, -0.8983,  ..., -0.2285, -0.7309, -0.1355],
#         [ 1.1234,  1.3371, -0.9366,  ..., -0.2695, -0.7135, -0.1133]])
# Text Report:  The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 5.44 mm, volume: 74.65 mm3.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Sample 3
# LIDC-LUNA Image embed:  tensor([[ 1.1225,  1.2871, -0.7375,  ..., -0.2817, -0.5134, -0.1494],
#         [ 1.1765,  1.2715, -0.7768,  ..., -0.2774, -0.6058, -0.1718],
#         [ 1.2247,  1.3023, -0.7694,  ..., -0.3949, -0.5529, -0.1681],
#         ...,
#         [ 1.1739,  1.3489, -0.8345,  ..., -0.3509, -0.5300, -0.0892],
#         [ 1.1447,  1.3481, -0.7107,  ..., -0.3381, -0.5545, -0.1256],
#         [ 1.1823,  1.4033, -0.7637,  ..., -0.3885, -0.5471, -0.0981]])
# Text Report:  The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Critical, diameter: 19.65 mm, volume: 3319.18 mm3.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Sample 4
# LIDC-LUNA Image embed:  tensor([[ 1.1060,  1.2253, -0.9733,  ..., -0.2203, -0.7264, -0.1483],
#         [ 1.1425,  1.2034, -1.0004,  ..., -0.2111, -0.7986, -0.1766],
#         [ 1.1996,  1.2372, -0.9882,  ..., -0.3158, -0.7557, -0.1682],
#         ...,
#         [ 1.1515,  1.2725, -1.0503,  ..., -0.2701, -0.7294, -0.0907],
#         [ 1.1180,  1.2832, -0.9391,  ..., -0.2614, -0.7513, -0.1299],
#         [ 1.1496,  1.3317, -0.9763,  ..., -0.3025, -0.7378, -0.1066]])
# Text Report:  The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Near Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Possible, diameter: 4.10 mm, volume: 31.68 mm3.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Sample 5
# LIDC-LUNA Image embed:  tensor([[ 1.0676,  1.2658, -0.9163,  ..., -0.1775, -0.7262, -0.1498],
#         [ 1.1038,  1.2411, -0.9383,  ..., -0.1660, -0.7942, -0.1752],
#         [ 1.1579,  1.2773, -0.9327,  ..., -0.2720, -0.7539, -0.1651],
#         ...,
#         [ 1.1091,  1.3130, -0.9889,  ..., -0.2285, -0.7261, -0.0898],
#         [ 1.0779,  1.3242, -0.8804,  ..., -0.2167, -0.7505, -0.1252],
#         [ 1.1072,  1.3723, -0.9208,  ..., -0.2552, -0.7344, -0.0968]])
# Text Report:  The lung nodule is characterized as follows: subtlety: Fairly Subtle, internalStructure: Soft Tissue, calcification: Absent, sphericity: Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Possible, diameter: 6.45 mm, volume: 139.12 mm3.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Sample 6
# LIDC-LUNA Image embed:  tensor([[ 1.0901,  1.2308, -0.9998,  ..., -0.1820, -0.7601, -0.1548],
#         [ 1.1206,  1.2076, -1.0239,  ..., -0.1688, -0.8250, -0.1849],
#         [ 1.1769,  1.2453, -1.0143,  ..., -0.2695, -0.7853, -0.1766],
#         ...,
#         [ 1.1289,  1.2750, -1.0732,  ..., -0.2253, -0.7603, -0.1029],
#         [ 1.0941,  1.2899, -0.9699,  ..., -0.2200, -0.7800, -0.1390],
#         [ 1.1225,  1.3331, -1.0075,  ..., -0.2514, -0.7640, -0.1123]])
# Text Report:  The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 5.23 mm, volume: 66.92 mm3.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Sample 7
# LIDC-LUNA Image embed:  tensor([[ 1.1018,  1.2393, -0.9167,  ..., -0.2082, -0.6548, -0.1601],
#         [ 1.1401,  1.2212, -0.9461,  ..., -0.2014, -0.7303, -0.1835],
#         [ 1.1925,  1.2577, -0.9313,  ..., -0.3022, -0.6897, -0.1769],
#         ...,
#         [ 1.1482,  1.2880, -0.9925,  ..., -0.2610, -0.6686, -0.1014],
#         [ 1.1114,  1.3027, -0.8856,  ..., -0.2535, -0.6816, -0.1361],
#         [ 1.1398,  1.3522, -0.9289,  ..., -0.2936, -0.6694, -0.1131]])
# Text Report:  The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Possible, diameter: 12.46 mm, volume: 1163.89 mm3.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Sample 8
# LIDC-LUNA Image embed:  tensor([[ 1.0943,  1.3212, -0.8650,  ..., -0.2396, -0.6008, -0.2035],
#         [ 1.1407,  1.2990, -0.9038,  ..., -0.2448, -0.6867, -0.2237],
#         [ 1.1906,  1.3339, -0.8890,  ..., -0.3529, -0.6412, -0.2155],
#         ...,
#         [ 1.1405,  1.3766, -0.9607,  ..., -0.3122, -0.6146, -0.1333],
#         [ 1.1061,  1.3796, -0.8302,  ..., -0.2973, -0.6384, -0.1711],
#         [ 1.1453,  1.4396, -0.8932,  ..., -0.3423, -0.6288, -0.1434]])
# Text Report:  The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid, margin: Near Poorly Defined, lobulation: No Lobulation, spiculation: Marked Spiculation, texture: Part Solid/Mixed, malignancy: Critical, diameter: 16.78 mm, volume: 1857.69 mm3.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Sample 9
# LIDC-LUNA Image embed:  tensor([[ 1.0844,  1.2671, -0.7583,  ..., -0.2652, -0.5687, -0.2077],
#         [ 1.1293,  1.2507, -0.7949,  ..., -0.2615, -0.6609, -0.2300],
#         [ 1.1784,  1.2833, -0.7872,  ..., -0.3665, -0.6096, -0.2278],
#         ...,
#         [ 1.1277,  1.3293, -0.8487,  ..., -0.3313, -0.5882, -0.1327],
#         [ 1.1034,  1.3317, -0.7264,  ..., -0.3193, -0.6118, -0.1790],
#         [ 1.1414,  1.3974, -0.7832,  ..., -0.3602, -0.6016, -0.1449]])
# Text Report:  The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid, margin: Near Sharp, lobulation: Nearly No Lobulation, spiculation: Nearly No Spiculation, texture: Solid, malignancy: Critical, diameter: 16.92 mm, volume: 2132.96 mm3.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Sample 10
# LIDC-LUNA Image embed:  tensor([[ 1.0619,  1.2301, -0.9401,  ..., -0.1833, -0.7069, -0.1416],
#         [ 1.0956,  1.2100, -0.9657,  ..., -0.1747, -0.7758, -0.1729],
#         [ 1.1525,  1.2474, -0.9573,  ..., -0.2807, -0.7353, -0.1613],
#         ...,
#         [ 1.1039,  1.2767, -1.0166,  ..., -0.2393, -0.7094, -0.0838],
#         [ 1.0666,  1.2888, -0.9050,  ..., -0.2280, -0.7323, -0.1190],
#         [ 1.0992,  1.3421, -0.9510,  ..., -0.2678, -0.7147, -0.0926]])
# Text Report:  The lung nodule is characterized as follows: subtlety: Moderately Subtle, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid, margin: Poorly Defined, lobulation: No Lobulation, spiculation: No Spiculation, texture: Non-Solid/GGO, malignancy: Indeterminate, diameter: 6.27 mm, volume: 76.84 mm3.
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Train the model

# %% [markdown]
# Let's train the model! Run the simply the cell below for training the model

# %%
if is_training:
    import torch
    import os
    
    epochs = 20
    lr = 5e-4
    
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    device = "cuda" if torch.cuda.is_available() else "cpu"
    
    # Diretório para salvar o melhor modelo
    checkpoint_dir = "./checkpoints"
    os.makedirs(checkpoint_dir, exist_ok=True)
    
    best_model_path = os.path.join(checkpoint_dir, "best_model.pt")
    best_loss = float('inf')  # Define a melhor perda inicial como infinita
    
    for epoch in range(epochs):
        start_time = time()
        train_loss = 0
        total_train_samples = 0
        total_val_samples = 0
        validation_loss = 0
        model.train()
        model.vision_model.training = True
      
        for idx, batch in enumerate(train_dataloader):
            input_ids = batch.pop("input_ids").to(device)
            embds = batch.pop("embds").to(device, torch.float32)
            attention_mask = batch.pop("attention_mask").to(device)
    
            outputs = model(input_ids=input_ids, attention_mask=attention_mask, pixel_values=embds, labels=input_ids)
            loss = outputs.loss
        
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
    
            train_loss += loss.item()
            total_train_samples += len(input_ids)
        
        model.eval()
        validation_loss = 0
        total_val_samples = 0
        correct = 0
        total = 0
        
        with torch.no_grad():
            for idx, batch in enumerate(test_dataloader):
                input_ids = batch.pop("input_ids").to(device)
                embds = batch.pop("embds").to(device, torch.float32)
                attention_mask = batch.pop("attention_mask").to(device)
                model.vision_model.training = True
                outputs = model(input_ids=input_ids, attention_mask=attention_mask, pixel_values=embds, labels=input_ids)
    
                loss = outputs.loss
                validation_loss += loss.item()
                total_val_samples += len(input_ids)
                model.vision_model.training = False
                
    
        avg_eval_loss = validation_loss / total_val_samples
        print(f"Validation Loss (Epoch {epoch}): {avg_eval_loss}")
    
        if avg_eval_loss < best_loss:
            best_loss = avg_eval_loss
            print(f"Saving best model with loss {best_loss}")
            model.save_pretrained(checkpoint_dir)  
            optimizer_state = {"optimizer": optimizer.state_dict(), "epoch": epoch}
            torch.save(optimizer_state, os.path.join(checkpoint_dir, "optimizer.pt")) 
    
    
        end_time = time()  
        epoch_duration = end_time - start_time  
    
        print(f'Epoch [{epoch+1}/{epochs}], \
                Train Loss: {(train_loss/total_train_samples):.4f}, \
                Val Loss: {(validation_loss/total_val_samples):.4f}, \
                Elapsed Time: {epoch_duration:.2f} sec'
             )

# %% [markdown]
# ## Inference

# %% [markdown]
# Let's check the results on our train dataset

# %%
import re
import numpy as np

def get_features(text):
    # Expressão regular para capturar key:value
    pattern = r'(\w+):\s*([^,]+)'
    
    # Expressão regular para extrair números float
    float_pattern = r'\d+\.\d+'
    
    # Encontrar todas as correspondências
    key_value_pairs = re.findall(pattern, text)
    
    # Converter para um dicionário, ajustando diameter e volume para float
    key_value_dict = {}
    for key, value in key_value_pairs:
        if key == 'follows': continue
        value = value.strip()
        if key in ["diameter", "volume"]:
            # Extrair número float usando regex
            float_match = re.search(float_pattern, value)
            if float_match:
                value = float(float_match.group())
        key_value_dict[key] = value

    return key_value_dict

def clip_text(text):

    # Extrair a parte da string até "malignancy"
    pattern = r'(.*malignancy:\s[^,]+)'

    # Busca a parte que termina com "malignancy"
    match = re.search(pattern, text)
    if match:
        text_until_malignancy = match.group(1)
        #print(text_until_malignancy)
        return text_until_malignancy
    else:
        print("Nenhum valor até 'malignancy' foi encontrado.")
        return text


def calculate_diameter(volume):
    return (6 * volume / np.pi) ** (1 / 3)

# %%
if is_evaluating:
    import os
    from bert_score import score
    from rouge_score import rouge_scorer

    malig_gt_labels = []
    malig_pred_labels = []
    malig_map = {'Remote': 1, 'Possible': 2, 'Indeterminate': 3, 'Doubtful': 4, 'Critical': 5}
    #malig_map = {'Remote': 1, 'Possible': 2, 'Doubtful': 3, 'Critical': 4}
    gt_diameters = []
    predicted_diameters = []
    predicted_diameters_2 = []

    device = "cuda" if torch.cuda.is_available() else "cpu"
    
    # Diretório para salvar o melhor modelo
    checkpoint_dir = "./checkpoints"
    os.makedirs(checkpoint_dir, exist_ok=True)
    
    model = Blip2ForConditionalGeneration.from_pretrained(
        checkpoint_dir,
        device_map="auto",
        torch_dtype=torch.float32
    )
    
    adapted_vit3d = ViT3DAdapter().to(device)
    model.vision_model = adapted_vit3d
    # Colocar o modelo em modo de avaliação, se necessário
    
    model.eval()
    
    validation_loss = 0
    total_val_samples = 0
    correct = 0
    total = 0
    
    precisions = []
    recalls = []
    f1s = []

    rouge_1 = []
    rouge_2 = []
    rouge_l = []
    
    
    with torch.no_grad():
        for idx, batch in enumerate(test_dataloader):
            input_ids = batch.pop("input_ids").to(device)
            embds = batch.pop("embds").to(device, torch.float32)
            attention_mask = batch.pop("attention_mask").to(device)
            # original_text = batch.pop("original_text")
            model.vision_model.training = True
            # outputs = model(input_ids=input_ids, pixel_values=embds, labels=input_ids)
            outputs = model(input_ids=input_ids, pixel_values=embds, labels=input_ids)
    
            loss = outputs.loss
            validation_loss += loss.item()
            total_val_samples += len(input_ids)
            model.vision_model.training = False
            generated_ids = model.generate(pixel_values=embds, temperature=0.0, do_sample=False, max_length=100)
            generated_caption = processor.batch_decode(generated_ids, skip_special_tokens=True)
            original_text = processor.batch_decode(input_ids, skip_special_tokens=True)
            
            for original, generated in zip(original_text, generated_caption):

                
                print("Original Text -->", original)
                print("\n")
                print("Generated Text -->", generated)
                print("\n")

                
                original_features = get_features(original)
                predicted_features = get_features(generated)

                print(predicted_features)
                
                original_value = original_features['malignancy']
                predicted_value = predicted_features['malignancy']
                            
                malig_gt_labels.append(malig_map[original_value])
                malig_pred_labels.append(malig_map[predicted_value])


                gt_diameters.append(original_features['diameter'])
                predicted_diameters.append(predicted_features['diameter'])
                predicted_diameters_2.append(calculate_diameter(predicted_features['volume']))
                
                print("Original malignancy -->", original_value)
                print("\n")
                print("Generated Text -->", predicted_value, original_features['diameter'], predicted_features['diameter'], calculate_diameter(predicted_features['volume']))
                print("\n")

                # Inicializa o calculador de ROUGE com as métricas desejadas
                scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
                
                # Calcula as pontuações ROUGE
                scores = scorer.score(clip_text(original), clip_text(generated))
                
                # Exibe as pontuações
                print("ROUGE-1:", scores['rouge1'])
                print("ROUGE-2:", scores['rouge2'])
                print("ROUGE-L:", scores['rougeL'])
            
                print("\n")

                rouge_1.append(scores['rouge1'])
                rouge_2.append(scores['rouge2'])
                rouge_l.append(scores['rougeL'])
                
    # print("Precision mean: ", torch.mean(precisions))
    # print("Recall mean: ", torch.mean(recalls))
    # print("F1 mean: ", torch.mean(f1s))
# Out:
# Loading checkpoint shards: 100%|██████████| 8/8 [00:05<00:00,  1.50it/s]
# /home/jovyan/envs/lung-multimodal/lib/python3.12/site-packages/transformers/generation/configuration_utils.py:590: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# Original Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Near Sharp, lobulation: Nearly No Lobulation, spiculation: Nearly No Spiculation, texture: Solid, malignancy: Doubtful, diameter: 13.64 mm, volume: 1482.34 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Near Sharp, lobulation: Nearly No Lobulation, spiculation: Nearly No Spiculation, texture: Solid, malignancy: Critical, diameter: 16.05 mm, volume: 1751.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Near Sharp', 'lobulation': 'Nearly No Lobulation', 'spiculation': 'Nearly No Spiculation', 'texture': 'Solid', 'malignancy': 'Critical', 'diameter': 16.05, 'volume': 1751.99}
# Original malignancy --> Doubtful
#
#
# Generated Text --> Critical 13.64 16.05 14.956994486175638
#
#
# ROUGE-1: Score(precision=0.96875, recall=0.96875, fmeasure=0.96875)
# ROUGE-2: Score(precision=0.967741935483871, recall=0.967741935483871, fmeasure=0.967741935483871)
# ROUGE-L: Score(precision=0.96875, recall=0.96875, fmeasure=0.96875)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Moderately Subtle, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Medium Margin, lobulation: Nearly No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 5.46 mm, volume: 63.29 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 5.99 mm, volume: 67.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Sharp', 'lobulation': 'No Lobulation', 'spiculation': 'No Spiculation', 'texture': 'Solid', 'malignancy': 'Indeterminate', 'diameter': 5.99, 'volume': 67.99}
# Original malignancy --> Indeterminate
#
#
# Generated Text --> Indeterminate 5.46 5.99 5.063865239285804
#
#
# ROUGE-1: Score(precision=0.9333333333333333, recall=0.875, fmeasure=0.9032258064516129)
# ROUGE-2: Score(precision=0.8275862068965517, recall=0.7741935483870968, fmeasure=0.7999999999999999)
# ROUGE-L: Score(precision=0.9333333333333333, recall=0.875, fmeasure=0.9032258064516129)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Round, margin: Near Sharp, lobulation: No Lobulation, spiculation: Nearly No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 8.21 mm, volume: 185.27 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 7.99 mm, volume: 207.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Sharp', 'lobulation': 'No Lobulation', 'spiculation': 'No Spiculation', 'texture': 'Solid', 'malignancy': 'Indeterminate', 'diameter': 7.99, 'volume': 207.99}
# Original malignancy --> Indeterminate
#
#
# Generated Text --> Indeterminate 8.21 7.99 7.351025752620398
#
#
# ROUGE-1: Score(precision=0.9666666666666667, recall=0.9354838709677419, fmeasure=0.9508196721311476)
# ROUGE-2: Score(precision=0.8620689655172413, recall=0.8333333333333334, fmeasure=0.847457627118644)
# ROUGE-L: Score(precision=0.9666666666666667, recall=0.9354838709677419, fmeasure=0.9508196721311476)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Fairly Subtle, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 6.10 mm, volume: 63.89 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 6.00 mm, volume: 66.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Sharp', 'lobulation': 'No Lobulation', 'spiculation': 'No Spiculation', 'texture': 'Solid', 'malignancy': 'Indeterminate', 'diameter': 6.0, 'volume': 66.99}
# Original malignancy --> Indeterminate
#
#
# Generated Text --> Indeterminate 6.1 6.0 5.038915998560362
#
#
# ROUGE-1: Score(precision=0.9333333333333333, recall=0.9333333333333333, fmeasure=0.9333333333333333)
# ROUGE-2: Score(precision=0.896551724137931, recall=0.896551724137931, fmeasure=0.896551724137931)
# ROUGE-L: Score(precision=0.9333333333333333, recall=0.9333333333333333, fmeasure=0.9333333333333333)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Moderately Subtle, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Poorly Defined, lobulation: Medium Lobulation, spiculation: Nearly No Spiculation, texture: Non-Solid/GGO, malignancy: Doubtful, diameter: 5.51 mm, volume: 44.65 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 6.32 mm, volume: 102.96 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Sharp', 'lobulation': 'No Lobulation', 'spiculation': 'No Spiculation', 'texture': 'Solid', 'malignancy': 'Indeterminate', 'diameter': 6.32, 'volume': 102.96}
# Original malignancy --> Doubtful
#
#
# Generated Text --> Indeterminate 5.51 6.32 5.815092631273869
#
#
# ROUGE-1: Score(precision=0.8666666666666667, recall=0.7647058823529411, fmeasure=0.8125)
# ROUGE-2: Score(precision=0.6551724137931034, recall=0.5757575757575758, fmeasure=0.6129032258064515)
# ROUGE-L: Score(precision=0.8666666666666667, recall=0.7647058823529411, fmeasure=0.8125)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid, margin: Medium Margin, lobulation: Nearly No Lobulation, spiculation: Medium Spiculation, texture: Solid, malignancy: Critical, diameter: 17.69 mm, volume: 3076.57 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Near Sharp, lobulation: Nearly No Lobulation, spiculation: Nearly No Spiculation, texture: Solid, malignancy: Critical, diameter: 21.88 mm, volume: 4590.96 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Near Sharp', 'lobulation': 'Nearly No Lobulation', 'spiculation': 'Nearly No Spiculation', 'texture': 'Solid', 'malignancy': 'Critical', 'diameter': 21.88, 'volume': 4590.96}
# Original malignancy --> Critical
#
#
# Generated Text --> Critical 17.69 21.88 20.620615716376424
#
#
# ROUGE-1: Score(precision=0.84375, recall=0.9, fmeasure=0.870967741935484)
# ROUGE-2: Score(precision=0.7419354838709677, recall=0.7931034482758621, fmeasure=0.7666666666666667)
# ROUGE-L: Score(precision=0.84375, recall=0.9, fmeasure=0.870967741935484)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Fairly Subtle, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Linear, margin: Near Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 4.34 mm, volume: 27.92 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 5.99 mm, volume: 67.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Sharp', 'lobulation': 'No Lobulation', 'spiculation': 'No Spiculation', 'texture': 'Solid', 'malignancy': 'Indeterminate', 'diameter': 5.99, 'volume': 67.99}
# Original malignancy --> Indeterminate
#
#
# Generated Text --> Indeterminate 4.34 5.99 5.063865239285804
#
#
# ROUGE-1: Score(precision=0.9, recall=0.8709677419354839, fmeasure=0.8852459016393444)
# ROUGE-2: Score(precision=0.7931034482758621, recall=0.7666666666666667, fmeasure=0.7796610169491527)
# ROUGE-L: Score(precision=0.9, recall=0.8709677419354839, fmeasure=0.8852459016393444)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid, margin: Sharp, lobulation: Medium Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Doubtful, diameter: 6.44 mm, volume: 158.92 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 5.99 mm, volume: 67.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Sharp', 'lobulation': 'No Lobulation', 'spiculation': 'No Spiculation', 'texture': 'Solid', 'malignancy': 'Indeterminate', 'diameter': 5.99, 'volume': 67.99}
# Original malignancy --> Doubtful
#
#
# Generated Text --> Indeterminate 6.44 5.99 5.063865239285804
#
#
# ROUGE-1: Score(precision=0.8666666666666667, recall=0.9285714285714286, fmeasure=0.896551724137931)
# ROUGE-2: Score(precision=0.7586206896551724, recall=0.8148148148148148, fmeasure=0.7857142857142857)
# ROUGE-L: Score(precision=0.8666666666666667, recall=0.9285714285714286, fmeasure=0.896551724137931)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: Near Marked Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 17.16 mm, volume: 1878.90 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Near Sharp, lobulation: Nearly No Lobulation, spiculation: Nearly No Spiculation, texture: Solid, malignancy: Critical, diameter: 20.88 mm, volume: 488.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Near Sharp', 'lobulation': 'Nearly No Lobulation', 'spiculation': 'Nearly No Spiculation', 'texture': 'Solid', 'malignancy': 'Critical', 'diameter': 20.88, 'volume': 488.99}
# Original malignancy --> Indeterminate
#
#
# Generated Text --> Critical 17.16 20.88 9.774632809453148
#
#
# ROUGE-1: Score(precision=0.875, recall=0.9333333333333333, fmeasure=0.9032258064516129)
# ROUGE-2: Score(precision=0.7419354838709677, recall=0.7931034482758621, fmeasure=0.7666666666666667)
# ROUGE-L: Score(precision=0.84375, recall=0.9, fmeasure=0.870967741935484)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Medium Margin, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Doubtful, diameter: 8.85 mm, volume: 244.33 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 9.06 mm, volume: 466.96 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Sharp', 'lobulation': 'No Lobulation', 'spiculation': 'No Spiculation', 'texture': 'Solid', 'malignancy': 'Indeterminate', 'diameter': 9.06, 'volume': 466.96}
# Original malignancy --> Doubtful
#
#
# Generated Text --> Indeterminate 8.85 9.06 9.625582470496875
#
#
# ROUGE-1: Score(precision=0.9333333333333333, recall=0.9032258064516129, fmeasure=0.9180327868852459)
# ROUGE-2: Score(precision=0.896551724137931, recall=0.8666666666666667, fmeasure=0.8813559322033899)
# ROUGE-L: Score(precision=0.9333333333333333, recall=0.9032258064516129, fmeasure=0.9180327868852459)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid, margin: Medium Margin, lobulation: No Lobulation, spiculation: Marked Spiculation, texture: Solid, malignancy: Doubtful, diameter: 10.91 mm, volume: 651.54 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Near Sharp, lobulation: Nearly No Lobulation, spiculation: Nearly No Spiculation, texture: Solid, malignancy: Critical, diameter: 16.05 mm, volume: 1751.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Near Sharp', 'lobulation': 'Nearly No Lobulation', 'spiculation': 'Nearly No Spiculation', 'texture': 'Solid', 'malignancy': 'Critical', 'diameter': 16.05, 'volume': 1751.99}
# Original malignancy --> Doubtful
#
#
# Generated Text --> Critical 10.91 16.05 14.956994486175638
#
#
# ROUGE-1: Score(precision=0.78125, recall=0.8620689655172413, fmeasure=0.8196721311475409)
# ROUGE-2: Score(precision=0.6451612903225806, recall=0.7142857142857143, fmeasure=0.6779661016949152)
# ROUGE-L: Score(precision=0.78125, recall=0.8620689655172413, fmeasure=0.8196721311475409)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 7.07 mm, volume: 182.32 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 6.32 mm, volume: 102.96 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Sharp', 'lobulation': 'No Lobulation', 'spiculation': 'No Spiculation', 'texture': 'Solid', 'malignancy': 'Indeterminate', 'diameter': 6.32, 'volume': 102.96}
# Original malignancy --> Indeterminate
#
#
# Generated Text --> Indeterminate 7.07 6.32 5.815092631273869
#
#
# ROUGE-1: Score(precision=0.9666666666666667, recall=1.0, fmeasure=0.983050847457627)
# ROUGE-2: Score(precision=0.9310344827586207, recall=0.9642857142857143, fmeasure=0.9473684210526316)
# ROUGE-L: Score(precision=0.9666666666666667, recall=1.0, fmeasure=0.983050847457627)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Moderately Subtle, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Medium Margin, lobulation: Nearly No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Remote, diameter: 4.21 mm, volume: 47.39 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 5.99 mm, volume: 72.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Sharp', 'lobulation': 'No Lobulation', 'spiculation': 'No Spiculation', 'texture': 'Solid', 'malignancy': 'Indeterminate', 'diameter': 5.99, 'volume': 72.99}
# Original malignancy --> Remote
#
#
# Generated Text --> Indeterminate 4.21 5.99 5.185073461250795
#
#
# ROUGE-1: Score(precision=0.9, recall=0.84375, fmeasure=0.870967741935484)
# ROUGE-2: Score(precision=0.7931034482758621, recall=0.7419354838709677, fmeasure=0.7666666666666667)
# ROUGE-L: Score(precision=0.9, recall=0.84375, fmeasure=0.870967741935484)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Round, margin: Near Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Doubtful, diameter: 6.97 mm, volume: 131.05 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 6.99 mm, volume: 112.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Sharp', 'lobulation': 'No Lobulation', 'spiculation': 'No Spiculation', 'texture': 'Solid', 'malignancy': 'Indeterminate', 'diameter': 6.99, 'volume': 112.99}
# Original malignancy --> Doubtful
#
#
# Generated Text --> Indeterminate 6.97 6.99 5.998101290319554
#
#
# ROUGE-1: Score(precision=0.9, recall=0.9310344827586207, fmeasure=0.9152542372881356)
# ROUGE-2: Score(precision=0.7931034482758621, recall=0.8214285714285714, fmeasure=0.8070175438596492)
# ROUGE-L: Score(precision=0.9, recall=0.9310344827586207, fmeasure=0.9152542372881356)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Near Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 3.82 mm, volume: 27.64 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Fairly Subtle, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 4.99 mm, volume: 35.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Sharp', 'lobulation': 'No Lobulation', 'spiculation': 'No Spiculation', 'texture': 'Solid', 'malignancy': 'Indeterminate', 'diameter': 4.99, 'volume': 35.99}
# Original malignancy --> Indeterminate
#
#
# Generated Text --> Indeterminate 3.82 4.99 4.096325019924129
#
#
# ROUGE-1: Score(precision=0.9333333333333333, recall=0.9032258064516129, fmeasure=0.9180327868852459)
# ROUGE-2: Score(precision=0.8620689655172413, recall=0.8333333333333334, fmeasure=0.847457627118644)
# ROUGE-L: Score(precision=0.9333333333333333, recall=0.9032258064516129, fmeasure=0.9180327868852459)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid, margin: Near Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid/Mixed, malignancy: Doubtful, diameter: 7.31 mm, volume: 70.85 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 7.99 mm, volume: 207.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Sharp', 'lobulation': 'No Lobulation', 'spiculation': 'No Spiculation', 'texture': 'Solid', 'malignancy': 'Indeterminate', 'diameter': 7.99, 'volume': 207.99}
# Original malignancy --> Doubtful
#
#
# Generated Text --> Indeterminate 7.31 7.99 7.351025752620398
#
#
# ROUGE-1: Score(precision=0.9333333333333333, recall=0.9032258064516129, fmeasure=0.9180327868852459)
# ROUGE-2: Score(precision=0.8275862068965517, recall=0.8, fmeasure=0.8135593220338982)
# ROUGE-L: Score(precision=0.9333333333333333, recall=0.9032258064516129, fmeasure=0.9180327868852459)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid, margin: Near Poorly Defined, lobulation: Medium Lobulation, spiculation: Nearly No Spiculation, texture: Solid/Mixed, malignancy: Doubtful, diameter: 7.13 mm, volume: 213.24 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 6.99 mm, volume: 112.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Sharp', 'lobulation': 'No Lobulation', 'spiculation': 'No Spiculation', 'texture': 'Solid', 'malignancy': 'Indeterminate', 'diameter': 6.99, 'volume': 112.99}
# Original malignancy --> Doubtful
#
#
# Generated Text --> Indeterminate 7.13 6.99 5.998101290319554
#
#
# ROUGE-1: Score(precision=0.8666666666666667, recall=0.7878787878787878, fmeasure=0.8253968253968254)
# ROUGE-2: Score(precision=0.6896551724137931, recall=0.625, fmeasure=0.6557377049180328)
# ROUGE-L: Score(precision=0.8666666666666667, recall=0.7878787878787878, fmeasure=0.8253968253968254)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Solid, sphericity: Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Remote, diameter: 5.67 mm, volume: 75.26 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 5.99 mm, volume: 66.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Sharp', 'lobulation': 'No Lobulation', 'spiculation': 'No Spiculation', 'texture': 'Solid', 'malignancy': 'Indeterminate', 'diameter': 5.99, 'volume': 66.99}
# Original malignancy --> Remote
#
#
# Generated Text --> Indeterminate 5.67 5.99 5.038915998560362
#
#
# ROUGE-1: Score(precision=0.8666666666666667, recall=0.9285714285714286, fmeasure=0.896551724137931)
# ROUGE-2: Score(precision=0.7586206896551724, recall=0.8148148148148148, fmeasure=0.7857142857142857)
# ROUGE-L: Score(precision=0.8666666666666667, recall=0.9285714285714286, fmeasure=0.896551724137931)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid, margin: Near Sharp, lobulation: Near Marked Lobulation, spiculation: Marked Spiculation, texture: Solid, malignancy: Doubtful, diameter: 19.35 mm, volume: 2635.38 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Near Sharp, lobulation: Nearly No Lobulation, spiculation: Nearly No Spiculation, texture: Solid, malignancy: Critical, diameter: 16.88 mm, volume: 2248.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Near Sharp', 'lobulation': 'Nearly No Lobulation', 'spiculation': 'Nearly No Spiculation', 'texture': 'Solid', 'malignancy': 'Critical', 'diameter': 16.88, 'volume': 2248.99}
# Original malignancy --> Doubtful
#
#
# Generated Text --> Critical 19.35 16.88 16.25534909417711
#
#
# ROUGE-1: Score(precision=0.8125, recall=0.8666666666666667, fmeasure=0.8387096774193549)
# ROUGE-2: Score(precision=0.7096774193548387, recall=0.7586206896551724, fmeasure=0.7333333333333333)
# ROUGE-L: Score(precision=0.8125, recall=0.8666666666666667, fmeasure=0.8387096774193549)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Fairly Subtle, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 4.67 mm, volume: 73.89 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 5.99 mm, volume: 66.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Sharp', 'lobulation': 'No Lobulation', 'spiculation': 'No Spiculation', 'texture': 'Solid', 'malignancy': 'Indeterminate', 'diameter': 5.99, 'volume': 66.99}
# Original malignancy --> Indeterminate
#
#
# Generated Text --> Indeterminate 4.67 5.99 5.038915998560362
#
#
# ROUGE-1: Score(precision=0.9333333333333333, recall=0.9333333333333333, fmeasure=0.9333333333333333)
# ROUGE-2: Score(precision=0.896551724137931, recall=0.896551724137931, fmeasure=0.896551724137931)
# ROUGE-L: Score(precision=0.9333333333333333, recall=0.9333333333333333, fmeasure=0.9333333333333333)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Fairly Subtle, internalStructure: Soft Tissue, calcification: Absent, sphericity: Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 7.92 mm, volume: 199.64 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 6.32 mm, volume: 102.96 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Sharp', 'lobulation': 'No Lobulation', 'spiculation': 'No Spiculation', 'texture': 'Solid', 'malignancy': 'Indeterminate', 'diameter': 6.32, 'volume': 102.96}
# Original malignancy --> Indeterminate
#
#
# Generated Text --> Indeterminate 7.92 6.32 5.815092631273869
#
#
# ROUGE-1: Score(precision=0.9, recall=0.9310344827586207, fmeasure=0.9152542372881356)
# ROUGE-2: Score(precision=0.8275862068965517, recall=0.8571428571428571, fmeasure=0.8421052631578947)
# ROUGE-L: Score(precision=0.9, recall=0.9310344827586207, fmeasure=0.9152542372881356)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Solid, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Remote, diameter: 7.40 mm, volume: 218.19 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 6.32 mm, volume: 102.96 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Sharp', 'lobulation': 'No Lobulation', 'spiculation': 'No Spiculation', 'texture': 'Solid', 'malignancy': 'Indeterminate', 'diameter': 6.32, 'volume': 102.96}
# Original malignancy --> Remote
#
#
# Generated Text --> Indeterminate 7.4 6.32 5.815092631273869
#
#
# ROUGE-1: Score(precision=0.9, recall=0.9310344827586207, fmeasure=0.9152542372881356)
# ROUGE-2: Score(precision=0.8275862068965517, recall=0.8571428571428571, fmeasure=0.8421052631578947)
# ROUGE-L: Score(precision=0.9, recall=0.9310344827586207, fmeasure=0.9152542372881356)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Popcorn, sphericity: Ovoid, margin: Near Sharp, lobulation: Medium Lobulation, spiculation: Nearly No Spiculation, texture: Solid, malignancy: Remote, diameter: 23.93 mm, volume: 6700.44 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Near Sharp, lobulation: Nearly No Lobulation, spiculation: Nearly No Spiculation, texture: Solid, malignancy: Critical, diameter: 24.88 mm, volume: 8073.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Near Sharp', 'lobulation': 'Nearly No Lobulation', 'spiculation': 'Nearly No Spiculation', 'texture': 'Solid', 'malignancy': 'Critical', 'diameter': 24.88, 'volume': 8073.99}
# Original malignancy --> Remote
#
#
# Generated Text --> Critical 23.93 24.88 24.89028455330589
#
#
# ROUGE-1: Score(precision=0.84375, recall=0.9, fmeasure=0.870967741935484)
# ROUGE-2: Score(precision=0.7419354838709677, recall=0.7931034482758621, fmeasure=0.7666666666666667)
# ROUGE-L: Score(precision=0.84375, recall=0.9, fmeasure=0.870967741935484)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Solid, sphericity: Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Remote, diameter: 5.51 mm, volume: 55.62 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 5.99 mm, volume: 66.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Sharp', 'lobulation': 'No Lobulation', 'spiculation': 'No Spiculation', 'texture': 'Solid', 'malignancy': 'Indeterminate', 'diameter': 5.99, 'volume': 66.99}
# Original malignancy --> Remote
#
#
# Generated Text --> Indeterminate 5.51 5.99 5.038915998560362
#
#
# ROUGE-1: Score(precision=0.8666666666666667, recall=0.9285714285714286, fmeasure=0.896551724137931)
# ROUGE-2: Score(precision=0.7586206896551724, recall=0.8148148148148148, fmeasure=0.7857142857142857)
# ROUGE-L: Score(precision=0.8666666666666667, recall=0.9285714285714286, fmeasure=0.896551724137931)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid, margin: Near Sharp, lobulation: Nearly No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Critical, diameter: 11.48 mm, volume: 691.92 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Near Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Critical, diameter: 16.05 mm, volume: 1651.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Near Sharp', 'lobulation': 'No Lobulation', 'spiculation': 'No Spiculation', 'texture': 'Solid', 'malignancy': 'Critical', 'diameter': 16.05, 'volume': 1651.99}
# Original malignancy --> Critical
#
#
# Generated Text --> Critical 11.48 16.05 14.66683019319713
#
#
# ROUGE-1: Score(precision=0.9666666666666667, recall=0.9666666666666667, fmeasure=0.9666666666666667)
# ROUGE-2: Score(precision=0.896551724137931, recall=0.896551724137931, fmeasure=0.896551724137931)
# ROUGE-L: Score(precision=0.9666666666666667, recall=0.9666666666666667, fmeasure=0.9666666666666667)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid, margin: Near Sharp, lobulation: Nearly No Lobulation, spiculation: Nearly No Spiculation, texture: Non-Solid/GGO, malignancy: Doubtful, diameter: 8.12 mm, volume: 166.31 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 6.32 mm, volume: 102.96 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Sharp', 'lobulation': 'No Lobulation', 'spiculation': 'No Spiculation', 'texture': 'Solid', 'malignancy': 'Indeterminate', 'diameter': 6.32, 'volume': 102.96}
# Original malignancy --> Doubtful
#
#
# Generated Text --> Indeterminate 8.12 6.32 5.815092631273869
#
#
# ROUGE-1: Score(precision=0.9333333333333333, recall=0.8235294117647058, fmeasure=0.8749999999999999)
# ROUGE-2: Score(precision=0.7241379310344828, recall=0.6363636363636364, fmeasure=0.6774193548387097)
# ROUGE-L: Score(precision=0.9333333333333333, recall=0.8235294117647058, fmeasure=0.8749999999999999)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Fairly Subtle, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Poorly Defined, lobulation: No Lobulation, spiculation: Nearly No Spiculation, texture: Non-Solid/GGO, malignancy: Doubtful, diameter: 10.61 mm, volume: 615.33 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Near Sharp, lobulation: Nearly No Lobulation, spiculation: Nearly No Spiculation, texture: Solid, malignancy: Critical, diameter: 16.05 mm, volume: 1751.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Near Sharp', 'lobulation': 'Nearly No Lobulation', 'spiculation': 'Nearly No Spiculation', 'texture': 'Solid', 'malignancy': 'Critical', 'diameter': 16.05, 'volume': 1751.99}
# Original malignancy --> Doubtful
#
#
# Generated Text --> Critical 10.61 16.05 14.956994486175638
#
#
# ROUGE-1: Score(precision=0.84375, recall=0.7941176470588235, fmeasure=0.8181818181818182)
# ROUGE-2: Score(precision=0.6774193548387096, recall=0.6363636363636364, fmeasure=0.65625)
# ROUGE-L: Score(precision=0.84375, recall=0.7941176470588235, fmeasure=0.8181818181818182)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid, margin: Near Sharp, lobulation: Nearly No Lobulation, spiculation: Medium Spiculation, texture: Solid, malignancy: Possible, diameter: 5.60 mm, volume: 71.05 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 4.99 mm, volume: 35.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Sharp', 'lobulation': 'No Lobulation', 'spiculation': 'No Spiculation', 'texture': 'Solid', 'malignancy': 'Indeterminate', 'diameter': 4.99, 'volume': 35.99}
# Original malignancy --> Possible
#
#
# Generated Text --> Indeterminate 5.6 4.99 4.096325019924129
#
#
# ROUGE-1: Score(precision=0.8666666666666667, recall=0.8666666666666667, fmeasure=0.8666666666666667)
# ROUGE-2: Score(precision=0.6896551724137931, recall=0.6896551724137931, fmeasure=0.6896551724137931)
# ROUGE-L: Score(precision=0.8666666666666667, recall=0.8666666666666667, fmeasure=0.8666666666666667)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Fairly Subtle, internalStructure: Soft Tissue, calcification: Absent, sphericity: Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 4.98 mm, volume: 56.77 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 5.99 mm, volume: 67.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Sharp', 'lobulation': 'No Lobulation', 'spiculation': 'No Spiculation', 'texture': 'Solid', 'malignancy': 'Indeterminate', 'diameter': 5.99, 'volume': 67.99}
# Original malignancy --> Indeterminate
#
#
# Generated Text --> Indeterminate 4.98 5.99 5.063865239285804
#
#
# ROUGE-1: Score(precision=0.9, recall=0.9310344827586207, fmeasure=0.9152542372881356)
# ROUGE-2: Score(precision=0.8275862068965517, recall=0.8571428571428571, fmeasure=0.8421052631578947)
# ROUGE-L: Score(precision=0.9, recall=0.9310344827586207, fmeasure=0.9152542372881356)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Fairly Subtle, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Near Poorly Defined, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 5.69 mm, volume: 27.02 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 5.99 mm, volume: 67.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Sharp', 'lobulation': 'No Lobulation', 'spiculation': 'No Spiculation', 'texture': 'Solid', 'malignancy': 'Indeterminate', 'diameter': 5.99, 'volume': 67.99}
# Original malignancy --> Indeterminate
#
#
# Generated Text --> Indeterminate 5.69 5.99 5.063865239285804
#
#
# ROUGE-1: Score(precision=0.9, recall=0.84375, fmeasure=0.870967741935484)
# ROUGE-2: Score(precision=0.8275862068965517, recall=0.7741935483870968, fmeasure=0.7999999999999999)
# ROUGE-L: Score(precision=0.9, recall=0.84375, fmeasure=0.870967741935484)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid, margin: Near Sharp, lobulation: No Lobulation, spiculation: Marked Spiculation, texture: Solid, malignancy: Critical, diameter: 22.04 mm, volume: 4799.72 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Near Sharp, lobulation: Nearly No Lobulation, spiculation: Nearly No Spiculation, texture: Solid, malignancy: Critical, diameter: 21.88 mm, volume: 4995.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Near Sharp', 'lobulation': 'Nearly No Lobulation', 'spiculation': 'Nearly No Spiculation', 'texture': 'Solid', 'malignancy': 'Critical', 'diameter': 21.88, 'volume': 4995.99}
# Original malignancy --> Critical
#
#
# Generated Text --> Critical 22.04 21.88 21.210015181353263
#
#
# ROUGE-1: Score(precision=0.875, recall=0.9655172413793104, fmeasure=0.9180327868852458)
# ROUGE-2: Score(precision=0.7741935483870968, recall=0.8571428571428571, fmeasure=0.8135593220338982)
# ROUGE-L: Score(precision=0.875, recall=0.9655172413793104, fmeasure=0.9180327868852458)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Extremely Subtle, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Near Sharp, lobulation: Nearly No Lobulation, spiculation: Nearly No Spiculation, texture: Solid/Mixed, malignancy: Indeterminate, diameter: 5.23 mm, volume: 19.66 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 5.99 mm, volume: 66.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Sharp', 'lobulation': 'No Lobulation', 'spiculation': 'No Spiculation', 'texture': 'Solid', 'malignancy': 'Indeterminate', 'diameter': 5.99, 'volume': 66.99}
# Original malignancy --> Indeterminate
#
#
# Generated Text --> Indeterminate 5.23 5.99 5.038915998560362
#
#
# ROUGE-1: Score(precision=0.9333333333333333, recall=0.8235294117647058, fmeasure=0.8749999999999999)
# ROUGE-2: Score(precision=0.7586206896551724, recall=0.6666666666666666, fmeasure=0.7096774193548386)
# ROUGE-L: Score(precision=0.9333333333333333, recall=0.8235294117647058, fmeasure=0.8749999999999999)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Moderately Subtle, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Near Poorly Defined, lobulation: No Lobulation, spiculation: No Spiculation, texture: Non-Solid/GGO, malignancy: Indeterminate, diameter: 4.70 mm, volume: 12.42 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 6.32 mm, volume: 102.96 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Sharp', 'lobulation': 'No Lobulation', 'spiculation': 'No Spiculation', 'texture': 'Solid', 'malignancy': 'Indeterminate', 'diameter': 6.32, 'volume': 102.96}
# Original malignancy --> Indeterminate
#
#
# Generated Text --> Indeterminate 4.7 6.32 5.815092631273869
#
#
# ROUGE-1: Score(precision=0.9333333333333333, recall=0.8235294117647058, fmeasure=0.8749999999999999)
# ROUGE-2: Score(precision=0.7931034482758621, recall=0.696969696969697, fmeasure=0.7419354838709677)
# ROUGE-L: Score(precision=0.9333333333333333, recall=0.8235294117647058, fmeasure=0.8749999999999999)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Round, margin: Near Sharp, lobulation: Medium Lobulation, spiculation: Nearly No Spiculation, texture: Solid, malignancy: Critical, diameter: 11.14 mm, volume: 625.62 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 12.06 mm, volume: 826.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Sharp', 'lobulation': 'No Lobulation', 'spiculation': 'No Spiculation', 'texture': 'Solid', 'malignancy': 'Indeterminate', 'diameter': 12.06, 'volume': 826.99}
# Original malignancy --> Critical
#
#
# Generated Text --> Indeterminate 11.14 12.06 11.645743271363902
#
#
# ROUGE-1: Score(precision=0.896551724137931, recall=0.8666666666666667, fmeasure=0.8813559322033899)
# ROUGE-2: Score(precision=0.75, recall=0.7241379310344828, fmeasure=0.736842105263158)
# ROUGE-L: Score(precision=0.896551724137931, recall=0.8666666666666667, fmeasure=0.8813559322033899)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Fairly Subtle, internalStructure: Soft Tissue, calcification: Absent, sphericity: Round, margin: Near Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 7.59 mm, volume: 184.17 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 6.99 mm, volume: 112.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Sharp', 'lobulation': 'No Lobulation', 'spiculation': 'No Spiculation', 'texture': 'Solid', 'malignancy': 'Indeterminate', 'diameter': 6.99, 'volume': 112.99}
# Original malignancy --> Indeterminate
#
#
# Generated Text --> Indeterminate 7.59 6.99 5.998101290319554
#
#
# ROUGE-1: Score(precision=0.9, recall=0.9, fmeasure=0.9)
# ROUGE-2: Score(precision=0.7931034482758621, recall=0.7931034482758621, fmeasure=0.7931034482758621)
# ROUGE-L: Score(precision=0.9, recall=0.9, fmeasure=0.9)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Fairly Subtle, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Near Sharp, lobulation: No Lobulation, spiculation: Nearly No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 4.54 mm, volume: 60.69 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 4.99 mm, volume: 35.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Sharp', 'lobulation': 'No Lobulation', 'spiculation': 'No Spiculation', 'texture': 'Solid', 'malignancy': 'Indeterminate', 'diameter': 4.99, 'volume': 35.99}
# Original malignancy --> Indeterminate
#
#
# Generated Text --> Indeterminate 4.54 4.99 4.096325019924129
#
#
# ROUGE-1: Score(precision=0.9333333333333333, recall=0.875, fmeasure=0.9032258064516129)
# ROUGE-2: Score(precision=0.8275862068965517, recall=0.7741935483870968, fmeasure=0.7999999999999999)
# ROUGE-L: Score(precision=0.9333333333333333, recall=0.875, fmeasure=0.9032258064516129)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 3.30 mm, volume: 5.76 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 4.99 mm, volume: 35.99 mm3.
#
#
# ...
#
#
# Generated Text --> Indeterminate 4.87 5.99 5.038915998560362
#
#
# ROUGE-1: Score(precision=1.0, recall=0.967741935483871, fmeasure=0.9836065573770492)
# ROUGE-2: Score(precision=0.9655172413793104, recall=0.9333333333333333, fmeasure=0.9491525423728815)
# ROUGE-L: Score(precision=1.0, recall=0.967741935483871, fmeasure=0.9836065573770492)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Round, margin: Near Poorly Defined, lobulation: Medium Lobulation, spiculation: No Spiculation, texture: Non-Solid/GGO, malignancy: Doubtful, diameter: 15.58 mm, volume: 1271.08 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Near Sharp, lobulation: Nearly No Lobulation, spiculation: Nearly No Spiculation, texture: Solid, malignancy: Critical, diameter: 16.05 mm, volume: 1751.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Near Sharp', 'lobulation': 'Nearly No Lobulation', 'spiculation': 'Nearly No Spiculation', 'texture': 'Solid', 'malignancy': 'Critical', 'diameter': 16.05, 'volume': 1751.99}
# Original malignancy --> Doubtful
#
#
# Generated Text --> Critical 15.58 16.05 14.956994486175638
#
#
# ROUGE-1: Score(precision=0.8125, recall=0.7878787878787878, fmeasure=0.8)
# ROUGE-2: Score(precision=0.5806451612903226, recall=0.5625, fmeasure=0.5714285714285715)
# ROUGE-L: Score(precision=0.8125, recall=0.7878787878787878, fmeasure=0.8)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Doubtful, diameter: 7.05 mm, volume: 193.71 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 6.32 mm, volume: 102.96 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Sharp', 'lobulation': 'No Lobulation', 'spiculation': 'No Spiculation', 'texture': 'Solid', 'malignancy': 'Indeterminate', 'diameter': 6.32, 'volume': 102.96}
# Original malignancy --> Doubtful
#
#
# Generated Text --> Indeterminate 7.05 6.32 5.815092631273869
#
#
# ROUGE-1: Score(precision=0.9333333333333333, recall=0.9655172413793104, fmeasure=0.9491525423728815)
# ROUGE-2: Score(precision=0.896551724137931, recall=0.9285714285714286, fmeasure=0.912280701754386)
# ROUGE-L: Score(precision=0.9333333333333333, recall=0.9655172413793104, fmeasure=0.9491525423728815)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid, margin: Near Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Possible, diameter: 6.22 mm, volume: 97.17 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 6.32 mm, volume: 102.96 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Sharp', 'lobulation': 'No Lobulation', 'spiculation': 'No Spiculation', 'texture': 'Solid', 'malignancy': 'Indeterminate', 'diameter': 6.32, 'volume': 102.96}
# Original malignancy --> Possible
#
#
# Generated Text --> Indeterminate 6.22 6.32 5.815092631273869
#
#
# ROUGE-1: Score(precision=0.9, recall=0.9310344827586207, fmeasure=0.9152542372881356)
# ROUGE-2: Score(precision=0.7931034482758621, recall=0.8214285714285714, fmeasure=0.8070175438596492)
# ROUGE-L: Score(precision=0.9, recall=0.9310344827586207, fmeasure=0.9152542372881356)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Fairly Subtle, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Near Poorly Defined, lobulation: No Lobulation, spiculation: No Spiculation, texture: Non-Solid/GGO, malignancy: Doubtful, diameter: 10.97 mm, volume: 742.72 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Near Sharp, lobulation: Nearly No Lobulation, spiculation: Nearly No Spiculation, texture: Solid, malignancy: Critical, diameter: 16.05 mm, volume: 1649.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Near Sharp', 'lobulation': 'Nearly No Lobulation', 'spiculation': 'Nearly No Spiculation', 'texture': 'Solid', 'malignancy': 'Critical', 'diameter': 16.05, 'volume': 1649.99}
# Original malignancy --> Doubtful
#
#
# Generated Text --> Critical 10.97 16.05 14.660908949512898
#
#
# ROUGE-1: Score(precision=0.84375, recall=0.7941176470588235, fmeasure=0.8181818181818182)
# ROUGE-2: Score(precision=0.6451612903225806, recall=0.6060606060606061, fmeasure=0.625)
# ROUGE-L: Score(precision=0.84375, recall=0.7941176470588235, fmeasure=0.8181818181818182)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: Nearly No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Critical, diameter: 17.99 mm, volume: 3133.67 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Near Sharp, lobulation: Nearly No Lobulation, spiculation: Nearly No Spiculation, texture: Solid, malignancy: Critical, diameter: 21.88 mm, volume: 4881.96 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Near Sharp', 'lobulation': 'Nearly No Lobulation', 'spiculation': 'Nearly No Spiculation', 'texture': 'Solid', 'malignancy': 'Critical', 'diameter': 21.88, 'volume': 4881.96}
# Original malignancy --> Critical
#
#
# Generated Text --> Critical 17.99 21.88 21.047403716646457
#
#
# ROUGE-1: Score(precision=0.9375, recall=1.0, fmeasure=0.967741935483871)
# ROUGE-2: Score(precision=0.8709677419354839, recall=0.9310344827586207, fmeasure=0.9)
# ROUGE-L: Score(precision=0.9375, recall=1.0, fmeasure=0.967741935483871)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Round, margin: Near Sharp, lobulation: Nearly No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Doubtful, diameter: 12.07 mm, volume: 758.97 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Near Sharp, lobulation: Nearly No Lobulation, spiculation: Nearly No Spiculation, texture: Solid, malignancy: Critical, diameter: 16.05 mm, volume: 1751.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Near Sharp', 'lobulation': 'Nearly No Lobulation', 'spiculation': 'Nearly No Spiculation', 'texture': 'Solid', 'malignancy': 'Critical', 'diameter': 16.05, 'volume': 1751.99}
# Original malignancy --> Doubtful
#
#
# Generated Text --> Critical 12.07 16.05 14.956994486175638
#
#
# ROUGE-1: Score(precision=0.90625, recall=0.9666666666666667, fmeasure=0.9354838709677419)
# ROUGE-2: Score(precision=0.8387096774193549, recall=0.896551724137931, fmeasure=0.8666666666666666)
# ROUGE-L: Score(precision=0.90625, recall=0.9666666666666667, fmeasure=0.9354838709677419)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Linear, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Possible, diameter: 7.13 mm, volume: 149.31 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 6.32 mm, volume: 102.96 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Sharp', 'lobulation': 'No Lobulation', 'spiculation': 'No Spiculation', 'texture': 'Solid', 'malignancy': 'Indeterminate', 'diameter': 6.32, 'volume': 102.96}
# Original malignancy --> Possible
#
#
# Generated Text --> Indeterminate 7.13 6.32 5.815092631273869
#
#
# ROUGE-1: Score(precision=0.9333333333333333, recall=0.9333333333333333, fmeasure=0.9333333333333333)
# ROUGE-2: Score(precision=0.896551724137931, recall=0.896551724137931, fmeasure=0.896551724137931)
# ROUGE-L: Score(precision=0.9333333333333333, recall=0.9333333333333333, fmeasure=0.9333333333333333)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Possible, diameter: 8.15 mm, volume: 226.75 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 6.99 mm, volume: 112.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Sharp', 'lobulation': 'No Lobulation', 'spiculation': 'No Spiculation', 'texture': 'Solid', 'malignancy': 'Indeterminate', 'diameter': 6.99, 'volume': 112.99}
# Original malignancy --> Possible
#
#
# Generated Text --> Indeterminate 8.15 6.99 5.998101290319554
#
#
# ROUGE-1: Score(precision=0.9333333333333333, recall=0.9655172413793104, fmeasure=0.9491525423728815)
# ROUGE-2: Score(precision=0.896551724137931, recall=0.9285714285714286, fmeasure=0.912280701754386)
# ROUGE-L: Score(precision=0.9333333333333333, recall=0.9655172413793104, fmeasure=0.9491525423728815)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Linear, margin: Medium Margin, lobulation: Medium Lobulation, spiculation: Medium Spiculation, texture: Part Solid/Mixed, malignancy: Critical, diameter: 22.23 mm, volume: 6819.39 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Near Sharp, lobulation: Nearly No Lobulation, spiculation: Nearly No Spiculation, texture: Solid, malignancy: Critical, diameter: 24.88 mm, volume: 8093.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Near Sharp', 'lobulation': 'Nearly No Lobulation', 'spiculation': 'Nearly No Spiculation', 'texture': 'Solid', 'malignancy': 'Critical', 'diameter': 24.88, 'volume': 8093.99}
# Original malignancy --> Critical
#
#
# Generated Text --> Critical 22.23 24.88 24.910819432148696
#
#
# ROUGE-1: Score(precision=0.78125, recall=0.78125, fmeasure=0.78125)
# ROUGE-2: Score(precision=0.5806451612903226, recall=0.5806451612903226, fmeasure=0.5806451612903226)
# ROUGE-L: Score(precision=0.78125, recall=0.78125, fmeasure=0.78125)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid, margin: Poorly Defined, lobulation: No Lobulation, spiculation: Nearly No Spiculation, texture: Non-Solid/GGO, malignancy: Critical, diameter: 13.05 mm, volume: 588.52 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Near Sharp, lobulation: Nearly No Lobulation, spiculation: Nearly No Spiculation, texture: Solid, malignancy: Critical, diameter: 16.05 mm, volume: 1751.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Near Sharp', 'lobulation': 'Nearly No Lobulation', 'spiculation': 'Nearly No Spiculation', 'texture': 'Solid', 'malignancy': 'Critical', 'diameter': 16.05, 'volume': 1751.99}
# Original malignancy --> Critical
#
#
# Generated Text --> Critical 13.05 16.05 14.956994486175638
#
#
# ROUGE-1: Score(precision=0.875, recall=0.8484848484848485, fmeasure=0.8615384615384615)
# ROUGE-2: Score(precision=0.6774193548387096, recall=0.65625, fmeasure=0.6666666666666667)
# ROUGE-L: Score(precision=0.875, recall=0.8484848484848485, fmeasure=0.8615384615384615)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Extremely Subtle, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid, margin: Near Poorly Defined, lobulation: Nearly No Lobulation, spiculation: Nearly No Spiculation, texture: Non-Solid/GGO, malignancy: Indeterminate, diameter: 4.52 mm, volume: 18.87 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Fairly Subtle, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Indeterminate, diameter: 4.99 mm, volume: 35.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Sharp', 'lobulation': 'No Lobulation', 'spiculation': 'No Spiculation', 'texture': 'Solid', 'malignancy': 'Indeterminate', 'diameter': 4.99, 'volume': 35.99}
# Original malignancy --> Indeterminate
#
#
# Generated Text --> Indeterminate 4.52 4.99 4.096325019924129
#
#
# ROUGE-1: Score(precision=0.9, recall=0.7714285714285715, fmeasure=0.8307692307692307)
# ROUGE-2: Score(precision=0.6551724137931034, recall=0.5588235294117647, fmeasure=0.6031746031746031)
# ROUGE-L: Score(precision=0.9, recall=0.7714285714285715, fmeasure=0.8307692307692307)
#
#
# Original Text --> The lung nodule is characterized as follows: subtlety: Moderately Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid, margin: Medium Margin, lobulation: Nearly No Lobulation, spiculation: Medium Spiculation, texture: Solid, malignancy: Critical, diameter: 11.23 mm, volume: 617.72 mm3.
#
#
# Generated Text --> The lung nodule is characterized as follows: subtlety: Obvious, internalStructure: Soft Tissue, calcification: Absent, sphericity: Ovoid/Round, margin: Sharp, lobulation: No Lobulation, spiculation: No Spiculation, texture: Solid, malignancy: Critical, diameter: 12.06 mm, volume: 826.99 mm3.
#
#
# {'internalStructure': 'Soft Tissue', 'calcification': 'Absent', 'sphericity': 'Ovoid/Round', 'margin': 'Sharp', 'lobulation': 'No Lobulation', 'spiculation': 'No Spiculation', 'texture': 'Solid', 'malignancy': 'Critical', 'diameter': 12.06, 'volume': 826.99}
# Original malignancy --> Critical
#
#
# Generated Text --> Critical 11.23 12.06 11.645743271363902
#
#
# ROUGE-1: Score(precision=0.896551724137931, recall=0.8387096774193549, fmeasure=0.8666666666666666)
# ROUGE-2: Score(precision=0.7142857142857143, recall=0.6666666666666666, fmeasure=0.689655172413793)
# ROUGE-L: Score(precision=0.896551724137931, recall=0.8387096774193549, fmeasure=0.8666666666666666)

# %%
import  numpy as np
print(f"Rouge 1 - Mean  {np.mean([f1.fmeasure for f1 in rouge_1])}")
print(f"Rouge 2 - Mean  {np.mean([f1.fmeasure for f1 in rouge_2])}")
print(f"Rouge L - Mean  {np.mean([f1.fmeasure for f1 in rouge_l])}")

# Definir os pesos para cada distância
weights = {0: 1.0, 1: 0.75, 2: 0.5, 3: 0.25, 4:0.125}
#weights = {0: 1.0, 1: 0.75, 2: 0.5, 3: 0.25}

# Calcular a acurácia ponderada
weighted_accuracy = sum([weights.get(abs(true - pred), 0) for true, pred in zip(malig_gt_labels, malig_pred_labels)]) / len(malig_gt_labels)

print("Acurácia Ponderada:", weighted_accuracy)
# Out:
# Rouge 1 - Mean  0.9063923729300132
# Rouge 2 - Mean  0.8105952820195067
# Rouge L - Mean  0.9055739339040524
# Acurácia Ponderada: 0.8066737288135594

# %%
from sklearn.metrics import classification_report
import pandas as pd


# Rótulos personalizados para as classes
target_names = ['Remote', 'Possible', 'Indeterminate', 'Doubtful', 'Critical']

# Gera o relatório de classificação com rótulos personalizados
report = classification_report(malig_gt_labels, malig_pred_labels, target_names=target_names, output_dict=True)

# Converte para um DataFrame e renomeia as colunas
report_df = pd.DataFrame(report).transpose()
report_df.columns = ['Precisão', 'Revocação', 'F1-Score', 'Suporte']

print(report_df)
# Out:
#                Precisão  Revocação  F1-Score    Suporte
# Remote         0.000000   0.000000  0.000000   34.00000
# Possible       0.000000   0.000000  0.000000   40.00000
# Indeterminate  0.427746   0.902439  0.580392   82.00000
# Doubtful       0.000000   0.000000  0.000000   42.00000
# Critical       0.523810   0.868421  0.653465   38.00000
# accuracy       0.453390   0.453390  0.453390    0.45339
# macro avg      0.190311   0.354172  0.246772  236.00000
# weighted avg   0.232966   0.453390  0.306881  236.00000
# /home/jovyan/envs/lung-multimodal/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jovyan/envs/lung-multimodal/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/jovyan/envs/lung-multimodal/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import math

def rmse(y_true, y_pred):
    
    # Passo 1: Calcular o erro quadrado para cada par de valores
    squared_errors = [(y - y_hat) ** 2 for y, y_hat in zip(y_true, y_pred)]
    
    # Passo 2: Calcular a média dos erros quadrados (MSE)
    mse = sum(squared_errors) / len(y_true)
    
    # Passo 3: Tirar a raiz quadrada do MSE para obter o RMSE
    rmse = math.sqrt(mse)
    
    return rmse

# %%
# Calcula o RMSE médio
resultado = rmse(gt_diameters, predicted_diameters)
print(f"RMSE DIAMETER1: {resultado} mm")
# Out:
# RMSE DIAMETER1: 2.5817479461843518 mm

# %%
# Calcula o RMSE médio
resultado = rmse(gt_diameters, predicted_diameters_2)
print(f"RMSE DIAMETER2: {resultado} mm")
# Out:
# RMSE DIAMETER2: 2.1910452302727306 mm

# %%
len(gt_diameters)
# Out:
# 236

# %%
#print(gt_diameters)
print("\n")
#print(predicted_diameters)

for idx, (gt, pre) in enumerate(zip(gt_diameters, predicted_diameters_2)):
    print(f"{idx+1}:           \tGt: {gt:.2f},           \tPred: {pre:.2f},          \t Error: {abs(gt-pre):.2f} mm")
# Out:
# 1:           	Gt: 13.64,           	Pred: 14.96,          	 Error: 1.32 mm
# 2:           	Gt: 5.46,           	Pred: 5.06,          	 Error: 0.40 mm
# 3:           	Gt: 8.21,           	Pred: 7.35,          	 Error: 0.86 mm
# 4:           	Gt: 6.10,           	Pred: 5.04,          	 Error: 1.06 mm
# 5:           	Gt: 5.51,           	Pred: 5.82,          	 Error: 0.31 mm
# 6:           	Gt: 17.69,           	Pred: 20.62,          	 Error: 2.93 mm
# 7:           	Gt: 4.34,           	Pred: 5.06,          	 Error: 0.72 mm
# 8:           	Gt: 6.44,           	Pred: 5.06,          	 Error: 1.38 mm
# 9:           	Gt: 17.16,           	Pred: 9.77,          	 Error: 7.39 mm
# 10:           	Gt: 8.85,           	Pred: 9.63,          	 Error: 0.78 mm
# 11:           	Gt: 10.91,           	Pred: 14.96,          	 Error: 4.05 mm
# 12:           	Gt: 7.07,           	Pred: 5.82,          	 Error: 1.25 mm
# 13:           	Gt: 4.21,           	Pred: 5.19,          	 Error: 0.98 mm
# 14:           	Gt: 6.97,           	Pred: 6.00,          	 Error: 0.97 mm
# 15:           	Gt: 3.82,           	Pred: 4.10,          	 Error: 0.28 mm
# 16:           	Gt: 7.31,           	Pred: 7.35,          	 Error: 0.04 mm
# 17:           	Gt: 7.13,           	Pred: 6.00,          	 Error: 1.13 mm
# 18:           	Gt: 5.67,           	Pred: 5.04,          	 Error: 0.63 mm
# 19:           	Gt: 19.35,           	Pred: 16.26,          	 Error: 3.09 mm
# 20:           	Gt: 4.67,           	Pred: 5.04,          	 Error: 0.37 mm
# 21:           	Gt: 7.92,           	Pred: 5.82,          	 Error: 2.10 mm
# 22:           	Gt: 7.40,           	Pred: 5.82,          	 Error: 1.58 mm
# 23:           	Gt: 23.93,           	Pred: 24.89,          	 Error: 0.96 mm
# 24:           	Gt: 5.51,           	Pred: 5.04,          	 Error: 0.47 mm
# 25:           	Gt: 11.48,           	Pred: 14.67,          	 Error: 3.19 mm
# 26:           	Gt: 8.12,           	Pred: 5.82,          	 Error: 2.30 mm
# 27:           	Gt: 10.61,           	Pred: 14.96,          	 Error: 4.35 mm
# 28:           	Gt: 5.60,           	Pred: 4.10,          	 Error: 1.50 mm
# 29:           	Gt: 4.98,           	Pred: 5.06,          	 Error: 0.08 mm
# 30:           	Gt: 5.69,           	Pred: 5.06,          	 Error: 0.63 mm
# 31:           	Gt: 22.04,           	Pred: 21.21,          	 Error: 0.83 mm
# 32:           	Gt: 5.23,           	Pred: 5.04,          	 Error: 0.19 mm
# 33:           	Gt: 4.70,           	Pred: 5.82,          	 Error: 1.12 mm
# 34:           	Gt: 11.14,           	Pred: 11.65,          	 Error: 0.51 mm
# 35:           	Gt: 7.59,           	Pred: 6.00,          	 Error: 1.59 mm
# 36:           	Gt: 4.54,           	Pred: 4.10,          	 Error: 0.44 mm
# 37:           	Gt: 3.30,           	Pred: 4.10,          	 Error: 0.80 mm
# 38:           	Gt: 13.45,           	Pred: 14.96,          	 Error: 1.51 mm
# 39:           	Gt: 7.53,           	Pred: 5.82,          	 Error: 1.71 mm
# 40:           	Gt: 4.44,           	Pred: 4.10,          	 Error: 0.34 mm
# 41:           	Gt: 10.17,           	Pred: 11.93,          	 Error: 1.76 mm
# 42:           	Gt: 8.74,           	Pred: 5.82,          	 Error: 2.92 mm
# 43:           	Gt: 9.75,           	Pred: 10.14,          	 Error: 0.39 mm
# 44:           	Gt: 7.38,           	Pred: 5.04,          	 Error: 2.34 mm
# 45:           	Gt: 5.21,           	Pred: 4.10,          	 Error: 1.11 mm
# 46:           	Gt: 4.62,           	Pred: 5.06,          	 Error: 0.44 mm
# 47:           	Gt: 5.25,           	Pred: 4.10,          	 Error: 1.15 mm
# 48:           	Gt: 17.75,           	Pred: 21.05,          	 Error: 3.30 mm
# 49:           	Gt: 8.39,           	Pred: 7.35,          	 Error: 1.04 mm
# 50:           	Gt: 14.21,           	Pred: 14.66,          	 Error: 0.45 mm
# 51:           	Gt: 10.44,           	Pred: 14.84,          	 Error: 4.40 mm
# 52:           	Gt: 3.90,           	Pred: 4.10,          	 Error: 0.20 mm
# 53:           	Gt: 18.21,           	Pred: 21.05,          	 Error: 2.84 mm
# 54:           	Gt: 4.99,           	Pred: 5.06,          	 Error: 0.07 mm
# 55:           	Gt: 4.72,           	Pred: 5.06,          	 Error: 0.34 mm
# 56:           	Gt: 15.27,           	Pred: 14.96,          	 Error: 0.31 mm
# 57:           	Gt: 5.86,           	Pred: 5.19,          	 Error: 0.67 mm
# 58:           	Gt: 5.24,           	Pred: 5.06,          	 Error: 0.18 mm
# 59:           	Gt: 6.44,           	Pred: 5.82,          	 Error: 0.62 mm
# 60:           	Gt: 4.93,           	Pred: 5.06,          	 Error: 0.13 mm
# 61:           	Gt: 4.36,           	Pred: 4.10,          	 Error: 0.26 mm
# 62:           	Gt: 10.42,           	Pred: 10.14,          	 Error: 0.28 mm
# 63:           	Gt: 8.49,           	Pred: 5.82,          	 Error: 2.67 mm
# 64:           	Gt: 7.18,           	Pred: 7.35,          	 Error: 0.17 mm
# 65:           	Gt: 7.20,           	Pred: 5.82,          	 Error: 1.38 mm
# 66:           	Gt: 4.36,           	Pred: 4.10,          	 Error: 0.26 mm
# 67:           	Gt: 4.14,           	Pred: 4.10,          	 Error: 0.04 mm
# 68:           	Gt: 5.56,           	Pred: 5.06,          	 Error: 0.50 mm
# 69:           	Gt: 3.88,           	Pred: 5.04,          	 Error: 1.16 mm
# 70:           	Gt: 7.81,           	Pred: 6.00,          	 Error: 1.81 mm
# 71:           	Gt: 5.05,           	Pred: 4.10,          	 Error: 0.95 mm
# 72:           	Gt: 9.82,           	Pred: 11.93,          	 Error: 2.11 mm
# 73:           	Gt: 3.39,           	Pred: 5.06,          	 Error: 1.67 mm
# 74:           	Gt: 22.30,           	Pred: 21.21,          	 Error: 1.09 mm
# 75:           	Gt: 5.07,           	Pred: 5.04,          	 Error: 0.03 mm
# 76:           	Gt: 4.51,           	Pred: 5.04,          	 Error: 0.53 mm
# 77:           	Gt: 11.65,           	Pred: 10.14,          	 Error: 1.51 mm
# 78:           	Gt: 5.83,           	Pred: 5.82,          	 Error: 0.01 mm
# 79:           	Gt: 13.69,           	Pred: 14.96,          	 Error: 1.27 mm
# 80:           	Gt: 12.76,           	Pred: 14.67,          	 Error: 1.91 mm
# 81:           	Gt: 14.86,           	Pred: 14.67,          	 Error: 0.19 mm
# 82:           	Gt: 4.90,           	Pred: 5.04,          	 Error: 0.14 mm
# 83:           	Gt: 5.90,           	Pred: 5.04,          	 Error: 0.86 mm
# 84:           	Gt: 4.29,           	Pred: 5.06,          	 Error: 0.77 mm
# 85:           	Gt: 18.02,           	Pred: 20.71,          	 Error: 2.69 mm
# 86:           	Gt: 6.46,           	Pred: 5.82,          	 Error: 0.64 mm
# 87:           	Gt: 7.39,           	Pred: 5.04,          	 Error: 2.35 mm
# 88:           	Gt: 21.58,           	Pred: 21.21,          	 Error: 0.37 mm
# 89:           	Gt: 6.20,           	Pred: 5.82,          	 Error: 0.38 mm
# 90:           	Gt: 16.02,           	Pred: 9.77,          	 Error: 6.25 mm
# 91:           	Gt: 3.43,           	Pred: 4.10,          	 Error: 0.67 mm
# 92:           	Gt: 7.85,           	Pred: 5.04,          	 Error: 2.81 mm
# 93:           	Gt: 4.47,           	Pred: 5.19,          	 Error: 0.72 mm
# 94:           	Gt: 7.57,           	Pred: 5.82,          	 Error: 1.75 mm
# 95:           	Gt: 4.98,           	Pred: 4.10,          	 Error: 0.88 mm
# 96:           	Gt: 16.83,           	Pred: 14.84,          	 Error: 1.99 mm
# 97:           	Gt: 3.69,           	Pred: 5.04,          	 Error: 1.35 mm
# 98:           	Gt: 13.34,           	Pred: 16.26,          	 Error: 2.92 mm
# 99:           	Gt: 9.00,           	Pred: 7.35,          	 Error: 1.65 mm
# 100:           	Gt: 3.89,           	Pred: 4.10,          	 Error: 0.21 mm
# 101:           	Gt: 11.48,           	Pred: 6.00,          	 Error: 5.48 mm
# 102:           	Gt: 4.86,           	Pred: 4.10,          	 Error: 0.76 mm
# 103:           	Gt: 9.70,           	Pred: 14.84,          	 Error: 5.14 mm
# 104:           	Gt: 17.14,           	Pred: 20.62,          	 Error: 3.48 mm
# 105:           	Gt: 7.90,           	Pred: 5.82,          	 Error: 2.08 mm
# 106:           	Gt: 6.07,           	Pred: 5.06,          	 Error: 1.01 mm
# 107:           	Gt: 6.26,           	Pred: 5.04,          	 Error: 1.22 mm
# 108:           	Gt: 4.65,           	Pred: 4.10,          	 Error: 0.55 mm
# 109:           	Gt: 12.03,           	Pred: 11.65,          	 Error: 0.38 mm
# 110:           	Gt: 14.91,           	Pred: 4.10,          	 Error: 10.81 mm
# 111:           	Gt: 12.61,           	Pred: 14.96,          	 Error: 2.35 mm
# 112:           	Gt: 4.47,           	Pred: 5.82,          	 Error: 1.35 mm
# 113:           	Gt: 4.47,           	Pred: 4.10,          	 Error: 0.37 mm
# 114:           	Gt: 6.66,           	Pred: 5.82,          	 Error: 0.84 mm
# 115:           	Gt: 4.46,           	Pred: 5.06,          	 Error: 0.60 mm
# 116:           	Gt: 12.17,           	Pred: 14.84,          	 Error: 2.67 mm
# 117:           	Gt: 4.77,           	Pred: 4.10,          	 Error: 0.67 mm
# 118:           	Gt: 7.30,           	Pred: 6.00,          	 Error: 1.30 mm
# 119:           	Gt: 4.21,           	Pred: 5.04,          	 Error: 0.83 mm
# 120:           	Gt: 5.21,           	Pred: 11.56,          	 Error: 6.35 mm
# 121:           	Gt: 5.90,           	Pred: 5.82,          	 Error: 0.08 mm
# 122:           	Gt: 13.81,           	Pred: 19.13,          	 Error: 5.32 mm
# 123:           	Gt: 6.49,           	Pred: 6.00,          	 Error: 0.49 mm
# 124:           	Gt: 7.21,           	Pred: 7.35,          	 Error: 0.14 mm
# 125:           	Gt: 23.04,           	Pred: 21.21,          	 Error: 1.83 mm
# 126:           	Gt: 7.97,           	Pred: 6.00,          	 Error: 1.97 mm
# 127:           	Gt: 8.83,           	Pred: 10.15,          	 Error: 1.32 mm
# 128:           	Gt: 14.17,           	Pred: 14.84,          	 Error: 0.67 mm
# 129:           	Gt: 3.81,           	Pred: 4.10,          	 Error: 0.29 mm
# 130:           	Gt: 6.27,           	Pred: 5.04,          	 Error: 1.23 mm
# 131:           	Gt: 5.81,           	Pred: 5.04,          	 Error: 0.77 mm
# 132:           	Gt: 5.18,           	Pred: 5.06,          	 Error: 0.12 mm
# 133:           	Gt: 4.13,           	Pred: 4.10,          	 Error: 0.03 mm
# 134:           	Gt: 4.67,           	Pred: 4.10,          	 Error: 0.57 mm
# 135:           	Gt: 4.84,           	Pred: 4.10,          	 Error: 0.74 mm
# 136:           	Gt: 7.67,           	Pred: 5.01,          	 Error: 2.66 mm
# 137:           	Gt: 6.29,           	Pred: 5.06,          	 Error: 1.23 mm
# 138:           	Gt: 5.26,           	Pred: 4.10,          	 Error: 1.16 mm
# 139:           	Gt: 7.23,           	Pred: 5.82,          	 Error: 1.41 mm
# 140:           	Gt: 9.76,           	Pred: 11.97,          	 Error: 2.21 mm
# 141:           	Gt: 7.93,           	Pred: 7.35,          	 Error: 0.58 mm
# 142:           	Gt: 4.99,           	Pred: 5.19,          	 Error: 0.20 mm
# 143:           	Gt: 16.18,           	Pred: 5.06,          	 Error: 11.12 mm
# 144:           	Gt: 16.18,           	Pred: 21.05,          	 Error: 4.87 mm
# 145:           	Gt: 6.71,           	Pred: 5.82,          	 Error: 0.89 mm
# 146:           	Gt: 9.65,           	Pred: 10.14,          	 Error: 0.49 mm
# 147:           	Gt: 20.04,           	Pred: 21.21,          	 Error: 1.17 mm
# 148:           	Gt: 4.78,           	Pred: 5.19,          	 Error: 0.41 mm
# 149:           	Gt: 15.69,           	Pred: 16.01,          	 Error: 0.32 mm
# 150:           	Gt: 7.66,           	Pred: 7.35,          	 Error: 0.31 mm
# 151:           	Gt: 10.04,           	Pred: 10.14,          	 Error: 0.10 mm
# 152:           	Gt: 3.59,           	Pred: 4.10,          	 Error: 0.51 mm
# 153:           	Gt: 5.23,           	Pred: 5.82,          	 Error: 0.59 mm
# 154:           	Gt: 4.88,           	Pred: 5.06,          	 Error: 0.18 mm
# 155:           	Gt: 14.16,           	Pred: 21.05,          	 Error: 6.89 mm
# 156:           	Gt: 10.76,           	Pred: 11.93,          	 Error: 1.17 mm
# 157:           	Gt: 4.30,           	Pred: 4.10,          	 Error: 0.20 mm
# 158:           	Gt: 7.48,           	Pred: 7.35,          	 Error: 0.13 mm
# 159:           	Gt: 5.98,           	Pred: 5.06,          	 Error: 0.92 mm
# 160:           	Gt: 4.52,           	Pred: 5.04,          	 Error: 0.52 mm
# 161:           	Gt: 6.77,           	Pred: 5.06,          	 Error: 1.71 mm
# 162:           	Gt: 6.17,           	Pred: 5.82,          	 Error: 0.35 mm
# 163:           	Gt: 5.36,           	Pred: 5.06,          	 Error: 0.30 mm
# 164:           	Gt: 4.37,           	Pred: 5.06,          	 Error: 0.69 mm
# 165:           	Gt: 6.39,           	Pred: 5.82,          	 Error: 0.57 mm
# 166:           	Gt: 12.82,           	Pred: 14.67,          	 Error: 1.85 mm
# 167:           	Gt: 6.31,           	Pred: 5.06,          	 Error: 1.25 mm
# 168:           	Gt: 6.24,           	Pred: 5.82,          	 Error: 0.42 mm
# 169:           	Gt: 8.71,           	Pred: 9.48,          	 Error: 0.77 mm
# 170:           	Gt: 5.26,           	Pred: 5.06,          	 Error: 0.20 mm
# 171:           	Gt: 4.74,           	Pred: 5.06,          	 Error: 0.32 mm
# 172:           	Gt: 4.87,           	Pred: 5.04,          	 Error: 0.17 mm
# 173:           	Gt: 4.40,           	Pred: 4.10,          	 Error: 0.30 mm
# 174:           	Gt: 6.87,           	Pred: 5.82,          	 Error: 1.05 mm
# 175:           	Gt: 11.48,           	Pred: 11.65,          	 Error: 0.17 mm
# 176:           	Gt: 11.02,           	Pred: 11.93,          	 Error: 0.91 mm
# 177:           	Gt: 18.38,           	Pred: 21.05,          	 Error: 2.67 mm
# 178:           	Gt: 17.40,           	Pred: 21.05,          	 Error: 3.65 mm
# 179:           	Gt: 4.96,           	Pred: 5.06,          	 Error: 0.10 mm
# 180:           	Gt: 5.48,           	Pred: 5.06,          	 Error: 0.42 mm
# 181:           	Gt: 9.59,           	Pred: 11.97,          	 Error: 2.38 mm
# 182:           	Gt: 12.14,           	Pred: 14.67,          	 Error: 2.53 mm
# 183:           	Gt: 5.28,           	Pred: 5.06,          	 Error: 0.22 mm
# 184:           	Gt: 5.09,           	Pred: 5.06,          	 Error: 0.03 mm
# 185:           	Gt: 9.76,           	Pred: 7.35,          	 Error: 2.41 mm
# 186:           	Gt: 4.94,           	Pred: 5.06,          	 Error: 0.12 mm
# 187:           	Gt: 12.08,           	Pred: 11.65,          	 Error: 0.43 mm
# 188:           	Gt: 5.84,           	Pred: 5.06,          	 Error: 0.78 mm
# 189:           	Gt: 10.47,           	Pred: 11.97,          	 Error: 1.50 mm
# 190:           	Gt: 3.34,           	Pred: 5.04,          	 Error: 1.70 mm
# 191:           	Gt: 3.92,           	Pred: 4.10,          	 Error: 0.18 mm
# 192:           	Gt: 8.22,           	Pred: 5.82,          	 Error: 2.40 mm
# 193:           	Gt: 6.38,           	Pred: 5.04,          	 Error: 1.34 mm
# 194:           	Gt: 4.33,           	Pred: 4.10,          	 Error: 0.23 mm
# 195:           	Gt: 12.57,           	Pred: 10.14,          	 Error: 2.43 mm
# 196:           	Gt: 11.41,           	Pred: 14.66,          	 Error: 3.25 mm
# 197:           	Gt: 15.39,           	Pred: 21.05,          	 Error: 5.66 mm
# 198:           	Gt: 5.87,           	Pred: 5.82,          	 Error: 0.05 mm
# 199:           	Gt: 5.19,           	Pred: 5.06,          	 Error: 0.13 mm
# 200:           	Gt: 17.16,           	Pred: 21.05,          	 Error: 3.89 mm
# 201:           	Gt: 4.14,           	Pred: 4.10,          	 Error: 0.04 mm
# 202:           	Gt: 6.31,           	Pred: 5.82,          	 Error: 0.49 mm
# 203:           	Gt: 15.48,           	Pred: 21.05,          	 Error: 5.57 mm
# 204:           	Gt: 14.20,           	Pred: 14.84,          	 Error: 0.64 mm
# 205:           	Gt: 8.10,           	Pred: 7.35,          	 Error: 0.75 mm
# 206:           	Gt: 13.65,           	Pred: 14.84,          	 Error: 1.19 mm
# 207:           	Gt: 4.29,           	Pred: 4.10,          	 Error: 0.19 mm
# 208:           	Gt: 10.32,           	Pred: 7.35,          	 Error: 2.97 mm
# 209:           	Gt: 5.58,           	Pred: 5.04,          	 Error: 0.54 mm
# 210:           	Gt: 4.46,           	Pred: 5.06,          	 Error: 0.60 mm
# 211:           	Gt: 3.74,           	Pred: 4.10,          	 Error: 0.36 mm
# 212:           	Gt: 8.27,           	Pred: 7.35,          	 Error: 0.92 mm
# 213:           	Gt: 18.87,           	Pred: 20.62,          	 Error: 1.75 mm
# 214:           	Gt: 6.66,           	Pred: 5.82,          	 Error: 0.84 mm
# 215:           	Gt: 5.65,           	Pred: 5.06,          	 Error: 0.59 mm
# 216:           	Gt: 5.22,           	Pred: 5.06,          	 Error: 0.16 mm
# 217:           	Gt: 4.80,           	Pred: 5.06,          	 Error: 0.26 mm
# 218:           	Gt: 9.77,           	Pred: 6.07,          	 Error: 3.70 mm
# 219:           	Gt: 16.64,           	Pred: 9.77,          	 Error: 6.87 mm
# 220:           	Gt: 5.13,           	Pred: 5.06,          	 Error: 0.07 mm
# 221:           	Gt: 6.77,           	Pred: 5.82,          	 Error: 0.95 mm
# 222:           	Gt: 4.83,           	Pred: 5.06,          	 Error: 0.23 mm
# 223:           	Gt: 3.66,           	Pred: 4.10,          	 Error: 0.44 mm
# 224:           	Gt: 4.87,           	Pred: 5.04,          	 Error: 0.17 mm
# 225:           	Gt: 15.58,           	Pred: 14.96,          	 Error: 0.62 mm
# 226:           	Gt: 7.05,           	Pred: 5.82,          	 Error: 1.23 mm
# 227:           	Gt: 6.22,           	Pred: 5.82,          	 Error: 0.40 mm
# 228:           	Gt: 10.97,           	Pred: 14.66,          	 Error: 3.69 mm
# 229:           	Gt: 17.99,           	Pred: 21.05,          	 Error: 3.06 mm
# 230:           	Gt: 12.07,           	Pred: 14.96,          	 Error: 2.89 mm
# 231:           	Gt: 7.13,           	Pred: 5.82,          	 Error: 1.31 mm
# 232:           	Gt: 8.15,           	Pred: 6.00,          	 Error: 2.15 mm
# 233:           	Gt: 22.23,           	Pred: 24.91,          	 Error: 2.68 mm
# 234:           	Gt: 13.05,           	Pred: 14.96,          	 Error: 1.91 mm
# 235:           	Gt: 4.52,           	Pred: 4.10,          	 Error: 0.42 mm
# 236:           	Gt: 11.23,           	Pred: 11.65,          	 Error: 0.42 mm
